# %% [markdown]
# # Personal details
# ---

# %% [markdown]
# |                                    |                        |
# | --                                 | --                     |
# | What´s your name?                  | Ann-Marie Davis        |
# | How old are you?                   | I’m nineteen           |
# | Where do you live?                 | In Los Angeles         |
# | What´s your address?               | 1146m Black Lion Drive |
# | Which country do you come from?    | The United State       |
# | What´s your date of birthday?      | 3 November, 1980       |
# | How long do you want to stay here? | Three weeks            |
# | Have you got a job?                | No, I’m a student      |

# %% [markdown]
# * boy
# * children
# * family
# * foreigner
# * girl
# * friend
# * teenager
# * woman
